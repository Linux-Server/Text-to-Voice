# %%
from transformers import BarkModel, AutoProcessor
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained("suno/bark")
model = BarkModel.from_pretrained("suno/bark-small", torch_dtype=torch.float16).to(device)
model =  model.to_bettertransformer()
# Out:
# The class `optimum.bettertransformers.transformation.BetterTransformer` is deprecated and will be removed in a future release.
# The BetterTransformer implementation does not support padding during training, as the fused kernels do not support attention masks. Beware that passing padded batched data during training may result in unexpected outputs. Please refer to https://huggingface.co/docs/optimum/bettertransformer/overview for more details.

# %%
voice_preset = "v2/en_speaker_6"

inputs = processor("Hello, how are you", voice_preset=voice_preset)

audio_array = model.generate(**inputs)
audio_array = audio_array.cpu().numpy().squeeze()
audio_array
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# array([0.00116  , 0.0005226, 0.0006676, ..., 0.000942 , 0.0009007,
#        0.000863 ], dtype=float16)

# %%
model.device
# Out:
# device(type='cpu')

# %%
from IPython.display import Audio

sample_rate = model.generation_config.sample_rate
Audio(audio_array, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 3.51 sec
#1.28 sec
# Out:
#   Cell In[15], line 4
#     pip install optimum
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install optimum
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting optimum
#   Downloading optimum-1.24.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: transformers>=4.29 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from optimum) (4.48.2)
# Requirement already satisfied: torch>=1.11 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from optimum) (2.6.0)
# Requirement already satisfied: packaging in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from optimum) (24.2)
# Requirement already satisfied: numpy in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from optimum) (2.1.3)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from optimum) (0.28.1)
# Requirement already satisfied: filelock in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from huggingface-hub>=0.8.0->optimum) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from huggingface-hub>=0.8.0->optimum) (2024.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from huggingface-hub>=0.8.0->optimum) (6.0.2)
# Requirement already satisfied: requests in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from huggingface-hub>=0.8.0->optimum) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from huggingface-hub>=0.8.0->optimum) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from huggingface-hub>=0.8.0->optimum) (4.12.2)
# Requirement already satisfied: networkx in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from torch>=1.11->optimum) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from torch>=1.11->optimum) (3.1.5)
# Requirement already satisfied: setuptools in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from torch>=1.11->optimum) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from torch>=1.11->optimum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.11->optimum) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from transformers>=4.29->optimum) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from transformers>=4.29->optimum) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from transformers>=4.29->optimum) (0.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from jinja2->torch>=1.11->optimum) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sachinmurali/anaconda3/envs/transformers/lib/python3.13/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (2025.1.31)
# Downloading optimum-1.24.0-py3-none-any.whl (433 kB)
# Installing collected packages: optimum
# Successfully installed optimum-1.24.0
